# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import matplotlib.pyplot as plt
import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd, numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Tencent

# %%
data = pd.read_csv('final_vg.csv')
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
data.shape
# Out:
# (16652, 11)

# %%
# data.tail()

# %%
data.Platform.value_counts()[:5]
# Out:
# DS      2163
# PS2     2161
# PS3     1330
# Wii     1327
# X360    1267
# Name: Platform, dtype: int64

# %%
data.Publisher.value_counts()
# Out:
# Electronic Arts                 1351
# Activision                      1014
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
#                                 ...
# TYO                                1
# Commseed                           1
# Fortyfive                          1
# Xing Entertainment                 1
# MediaQuest                         1
# Name: Publisher, Length: 578, dtype: int64

# %%
data.Year.value_counts().sort_index()
# Out:
# 1980.0      10
# 1981.0      47
# 1982.0      37
# 1983.0      18
# 1984.0      15
# 1985.0      16
# 1986.0      22
# 1987.0      17
# 1988.0      15
# 1989.0      18
# 1990.0      17
# 1991.0      42
# 1992.0      45
# 1993.0      61
# 1994.0     122
# 1995.0     221
# 1996.0     264
# 1997.0     291
# 1998.0     380
# 1999.0     339
# 2000.0     350
# 2001.0     483
# 2002.0     830
# 2003.0     777
# 2004.0     765
# 2005.0     943
# 2006.0    1009
# 2007.0    1204
# 2008.0    1429
# 2009.0    1432
# 2010.0    1261
# 2011.0    1140
# 2012.0     659
# 2013.0     548
# 2014.0     584
# 2015.0     615
# 2016.0     345
# 2017.0       5
# 2018.0       1
# 2019.0       2
# 2020.0       2
# Name: Year, dtype: int64

# %%
a = np.array([1,2,3])
a
# Out:
# array([1, 2, 3])

# %%
print(a)
# Out:
# [1 2 3]

# %%
x_val = [0, 1, 2]
y_val = [3, 5, 9]

plt.plot(x_val, y_val)

# %%
x_val = [0, 1, 2]
y_val = [3, 5, 9]

plt.plot(x_val, y_val)

plt.show()

# %%
# https://matplotlib.org/2.1.1/api/_as_gen/matplotlib.pyplot.plot.html

# %%
x_val = [0, 1, 2]
y_val = [3, 5, 9]

plt.plot(x_val, y_val, color = "red", linestyle = "--", linewidth = 1, marker = "*")

plt.show()

# %%
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
data.Genre.value_counts()
# Out:
# Action          3316
# Sports          2400
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
data["Genre"].value_counts()[:5]
# Out:
# Action          3316
# Sports          2400
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Name: Genre, dtype: int64

# %% [markdown]
# <!-- <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/019/567/original/image_2022-11-10_121820129.png?1668062911"> -->
#
#
# <!-- <img src="https://files.realpython.com/media/fig_map.bc8c7cabd823.png" />
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/019/579/original/image_2022-11-10_150131378.png?1668072693"> -->
#
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/019/615/original/image_2022-11-11_112008033.png?1668145811">

# %% [markdown]
# - Figure: The **overall window** or page that everything is drawn on.
#   - You can create multiple independent Figures in Jupyter.
#   - If you run the code in terminal, separate windows will pop-up
#
# - Axes: To the figure you can add multiple **Axes** which represents a plot
# - **Axis**: Simply the `x-axis` and `y-axis`
# - **Axes**: - It is the **area** on which the **data is plotted** with functions such as `plot()`
#     - **x-label**: Name of x-axis
#     - **y-label**: Name of y-axis
#     - **Major ticks**: subdivides the axis into major units. They appear by default during plotting
# - **Minor ticks**: subdivides the major tick units. They are by default hidden and can be toggled on.
# - **Title**: Title of each plot **(Axes)**, giving information about the same
# - **Legend**: describes the elements in the plot, blue and green curves in this case
# - **Suptitle**: The common title of all the plots

# %%
cat_counts = data["Genre"].value_counts()
cat_counts
# Out:
# Action          3316
# Sports          2400
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
cat_counts.values
# Out:
# array([3316, 2400, 1739, 1488, 1310, 1286, 1249,  886,  867,  848,  681,
#         582])

# %%
## First Bar Plot
cat_counts = data["Genre"].value_counts()

x = cat_counts.index
y = cat_counts.values


## start plotting 

plt.bar(x,y)

plt.show()

# %%
## First Bar Plot
cat_counts = data["Genre"].value_counts()

x = cat_counts.index
y = cat_counts.values


## start plotting 

plt.figure(figsize=(13,5))

plt.bar(x,y)

plt.show()

# %%
## First Bar Plot
cat_counts = data["Genre"].value_counts()

x = cat_counts.index
y = cat_counts.values


## start plotting 

plt.figure(figsize=(10,4))

plt.xticks(rotation = 45, fontsize = 9)

plt.bar(x,y)

plt.xlabel("Genre", fontsize = 12)
plt.ylabel("Count", fontsize = 12)

plt.show()

# %%
## First Bar Plot
cat_counts = data["Genre"].value_counts()

x = cat_counts.index
y = cat_counts.values


## start plotting 

plt.figure(figsize=(10,4))

plt.xticks(rotation = 45, fontsize = 9)

plt.bar(x,y, color = "purple", width = 0.8)

plt.xlabel("Genre", fontsize = 12)
plt.ylabel("Count", fontsize = 12)

plt.show()

# %%
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
## First Bar Plot
# cat_counts = data["Genre"].value_counts()

# x = cat_counts.index
# y = cat_counts.values

### COuntplot in Seaborn

plt.figure(figsize=(10, 5))

sns.countplot(data = data, x = "Genre")
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='count'>

# %%
## First Bar Plot
# cat_counts = data["Genre"].value_counts()

# x = cat_counts.index
# y = cat_counts.values

### COuntplot in Seaborn

# -- figuure size

# -- call the plotting function

# -- do all customizations

# -- plt.show

plt.figure(figsize=(8, 4))

sns.countplot(data = data, x = "Genre")

plt.xticks(rotation = 45)
plt.title("Count of Games Per Genre")

plt.show()

# %%
dec_order = list(data["Genre"].value_counts().index)  # descending order
dec_order
# Out:
# ['Action',
#  'Sports',
#  'Misc',
#  'Role-Playing',
#  'Shooter',
#  'Adventure',
#  'Racing',
#  'Platform',
#  'Simulation',
#  'Fighting',
#  'Strategy',
#  'Puzzle']

# %%
plt.figure(figsize=(8, 4))

sns.countplot(data = data, x = "Genre", order = dec_order)

plt.xticks(rotation = 45)
plt.title("Count of Games Per Genre")

plt.show()

# %%
dec_order[::-1] ## ascending order
# Out:
# ['Puzzle',
#  'Strategy',
#  'Fighting',
#  'Simulation',
#  'Platform',
#  'Racing',
#  'Adventure',
#  'Shooter',
#  'Role-Playing',
#  'Misc',
#  'Sports',
#  'Action']

# %%
plt.figure(figsize=(8, 4))

sns.countplot(data = data, x = "Genre", order = dec_order[::-1])

plt.xticks(rotation = 45)
plt.title("Count of Games Per Genre")

plt.show()

# %%
dec_order
# Out:
# ['Action',
#  'Sports',
#  'Misc',
#  'Role-Playing',
#  'Shooter',
#  'Adventure',
#  'Racing',
#  'Platform',
#  'Simulation',
#  'Fighting',
#  'Strategy',
#  'Puzzle']

# %%
random_order = ['Action',
 'Sports','Platform',
 'Simulation',
 'Fighting',
 'Strategy',
 'Puzzle', 'Misc',
 'Role-Playing',
 'Shooter',
 'Adventure',
 'Racing',]

# %%
plt.figure(figsize=(8, 4))

sns.countplot(data = data, x = "Genre", order = random_order)

plt.xticks(rotation = 45)
plt.title("Count of Games Per Genre")

plt.show()

# %%
plt.figure(figsize=(8, 4))

sns.countplot(data = data, 
              x = "Genre", 
              order = dec_order[::-1],
             color = "black")

plt.xticks(rotation = 45)
plt.title("Count of Games Per Genre")

plt.show()

# %%
# https://matplotlib.org/stable/gallery/color/named_colors.html  : Colors

# %%
plt.figure(figsize=(8, 4))

sns.countplot(data = data, 
              x = "Genre", 
              order = dec_order[::-1],
             color = "beige")

plt.xticks(rotation = 45)
plt.title("Count of Games Per Genre")

plt.show()

# %%
plt.figure(figsize=(8, 4))

sns.countplot(data = data, 
              x = "Genre", 
              order = dec_order[::-1],
             palette="viridis")

plt.xticks(rotation = 45)
plt.title("Count of Games Per Genre")

plt.show()

# %%
plt.figure(figsize=(8, 4))

sns.countplot(data = data, 
              x = "Genre", 
              order = dec_order[::-1],
             palette="BuGn")

plt.xticks(rotation = 45)
plt.title("Count of Games Per Genre")

plt.show()

# %%
# Pallete : https://www.practicalpythonfordatascience.com/ap_seaborn_palette

# %%
plt.figure(figsize=(8, 4))

ax = sns.countplot(data = data, 
              x = "Genre", 
              order = dec_order[::-1],
             palette="BuGn")

plt.xticks(rotation = 45)
plt.title("Count of Games Per Genre")

for i in ax.containers:
    ax.bar_label(i)

plt.show()

# %%
ax.containers ## iterable
# Out:
# [<BarContainer object of 12 artists>]

# %%
## First Bar Plot
cat_counts = data["Genre"].value_counts(normalize=True)*100

x = cat_counts.index
y = cat_counts.values

## start plotting 

plt.figure(figsize=(10,4))

plt.xticks(rotation = 45, fontsize = 9)

ax = plt.bar(x,y, color = "black", width = 0.8)

plt.xlabel("Genre", fontsize = 12)
plt.ylabel("Count", fontsize = 12)

plt.show()

# %%
cat_counts = data["Genre"].value_counts() 
x = cat_counts.index
y = cat_counts.values 

plt.figure(figsize=(10,4)) # --- fig size



plt.bar(x,y, color = "black", width = 0.8) ## plotting function

plt.xticks(rotation = 45, fontsize = 9) # all customzations
plt.xlabel("Genre", fontsize = 12)
plt.ylabel("Count", fontsize = 12) 

# plt.bar(x,y) 

plt.show()

# %%
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %% [markdown]
# ## Univariate (1 Var)

# %%
plt.figure(figsize=(8, 3))

ax = sns.countplot(data = data, 
              x = "Genre", 
              order = dec_order[::-1],
             palette="BuGn")

plt.xticks(rotation = 45)
plt.title("Count of Games Per Genre")

for i in ax.containers:
    ax.bar_label(i)

plt.show()

# %%
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
data["Year"].min()
# Out:
# 1980.0

# %%
data["Year"].max()
# Out:
# 2020.0

# %% [markdown]
# #### histogram

# %%
plt.hist(data["Year"])
# Out:
# (array([ 112.,   70.,   92.,  449., 1274., 2440., 3921., 5262., 2406.,
#          355.]),
#  array([1980., 1984., 1988., 1992., 1996., 2000., 2004., 2008., 2012.,
#         2016., 2020.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data["Year"], bins = 4)
# Out:
# (array([ 215., 1782., 9222., 5162.]),
#  array([1980., 1990., 2000., 2010., 2020.]),
#  <BarContainer object of 4 artists>)

# %%
plt.hist(data["Year"], bins = 4)
# Out:
# (array([ 215., 1782., 9222., 5162.]),
#  array([1980., 1990., 2000., 2010., 2020.]),
#  <BarContainer object of 4 artists>)

# %%
count, bins, random_text = plt.hist(data["Year"], bins = 4)

# %%
count
# Out:
# array([ 215., 1782., 9222., 5162.])

# %%
bins
# Out:
# array([1980., 1990., 2000., 2010., 2020.])

# %%
# random_text

# %%
a, b, _ = plt.hist(data["Year"], bins = 4)

# %%
a
# Out:
# array([ 215., 1782., 9222., 5162.])

# %%
b
# Out:
# array([1980., 1990., 2000., 2010., 2020.])

# %%
_
# Out:
# <BarContainer object of 4 artists>

# %%
plt.hist(data["Year"], bins = 4)
# Out:
# (array([ 215., 1782., 9222., 5162.]),
#  array([1980., 1990., 2000., 2010., 2020.]),
#  <BarContainer object of 4 artists>)

# %%
# plt.hist?

# %%
plt.hist(data["Year"])
plt.show()

# %%
sns.histplot(data["Year"], bins = 10)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Count'>

# %%
sns.histplot(data["Year"], bins = 10, kde = True)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Count'>

# %%
sns.displot(data = data, x = "Year", kind = "kde") ## kde/density plot

# %%
sns.histplot(data["Year"], bins = 10, kde = True)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Count'>

# %%
sns.histplot(data = data,x = "Year", bins = 10, kde = True)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Count'>

# %%
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
np.median(data["Global_Sales"])
# Out:
# 7.536613645

# %%
sns.boxplot(x = data["Global_Sales"])

plt.show()

# %%
(len(data[data["Global_Sales"]>20])/len(data))*100
# Out:
# 0.7566658659620467

# %%
max(data["Global_Sales"])
# Out:
# 30.55586186

# %%
data[data["Global_Sales"] == max(data["Global_Sales"])]
# Out:
#        Rank        Name Platform    Year   Genre Publisher  NA_Sales  \
# 15934     1  Wii Sports      Wii  2006.0  Sports  Nintendo  8.725452
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 15934  8.367985  6.327075     7.135349     30.555862

# %%
np.mean(data["Global_Sales"])
# Out:
# 8.457873345443602

# %%
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %% [markdown]
# ### Bivariate Plots (2 variable)

# %%
sns.lineplot(data = data, x = "Year", y = "Global_Sales")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Global_Sales'>

# %%
### I want to compare 2 games trend wrt year

# %%
data["Name"].valuescounts()
# Out:
# Ice Hockey                                       41
# Baseball                                         17
# Need for Speed: Most Wanted                      12
# Ratatouille                                       9
# FIFA 14                                           9
#                                                  ..
# Indy 500                                          1
# Indy Racing 2000                                  1
# Indycar Series 2005                               1
# inFAMOUS                                          1
# Zyuden Sentai Kyoryuger: Game de Gaburincho!!     1
# Name: Name, Length: 11493, dtype: int64

# %%
ih = data[data["Name"] == "Ice Hockey"]

# %%
ih.shape
# Out:
# (41, 11)

# %%
ba = data[data["Name"] == "Baseball"]

# %%
ba.shape
# Out:
# (17, 11)

# %%
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
ih
# Out:
#       Rank        Name Platform    Year   Genre   Publisher  NA_Sales  \
# 6073   639  Ice Hockey      NES  1988.0  Sports    Nintendo      0.44
# 6074  4027  Ice Hockey     2600  1980.0  Sports  Activision      0.39
# 6075  4149  Ice Hockey     2600  1991.0  Sports  Activision      0.61
# 6076  4149  Ice Hockey     2600  1992.0  Sports  Activision      0.65
# 6077  4149  Ice Hockey     SNES  1993.0  Sports  Activision      0.68
# 6078  4149  Ice Hockey     SNES  1994.0  Sports  Activision      0.75
# 6079  4149  Ice Hockey     SNES  1995.0  Sports  Activision      0.78
# 6080  4149  Ice Hockey     SNES  1996.0  Sports  Activision      0.76
# 6081  4149  Ice Hockey     SNES  1997.0  Sports  Activision      0.82
# 6082  4149  Ice Hockey     SNES  1998.0  Sports  Activision      0.88
# 6083  4149  Ice Hockey     SNES  1999.0  Sports  Activision      0.85
# 6084  4148  Ice Hockey     SNES  2000.0  Sports  Activision      0.84
# ...

# %%
plt.figure(figsize=(12,5))

sns.lineplot(data = ih,
            x = "Year",
            y = "NA_Sales",
             marker = "o")

plt.show()

# %%
plt.figure(figsize=(12,5))

sns.lineplot(data = ih, x = "Year", y = "NA_Sales", color = "green",marker = "o")
sns.lineplot(data = ba, x = "Year", y = "NA_Sales", color = "orange",marker = "o")

plt.show()

# %%
plt.figure(figsize=(12,5))

sns.lineplot(data = ih, x = "Year", y = "NA_Sales", color = "green",marker = "o")
sns.lineplot(data = ba, x = "Year", y = "NA_Sales", color = "orange",marker = "o")


plt.xticks(ih["Year"], rotation = 45, fontsize = 7, weight = "bold")

plt.show()

# %%
plt.figure(figsize=(12,5))

sns.lineplot(data = ih, x = "Year", y = "NA_Sales", color = "green",marker = "o")
sns.lineplot(data = ba, x = "Year", y = "NA_Sales", color = "orange",marker = "o")


plt.xticks(ih["Year"], rotation = 45, fontsize = 7, weight = "bold")

plt.grid(alpha = 0.3) ## 30% visibility

plt.show()

# %%
plt.figure(figsize=(12,5))

sns.lineplot(data = ih, x = "Year", y = "NA_Sales", color = "green",marker = "o",label = "Ice Hockey")
sns.lineplot(data = ba, x = "Year", y = "NA_Sales", color = "orange",marker = "o", label = "Baseball")


plt.xticks(ih["Year"], rotation = 45, fontsize = 7, weight = "bold")

plt.grid(alpha = 0.3) ## 30% visibility
plt.title("Trend of Ice Hockey vs Baseball Sales in NA Region")

plt.show()

# %%
plt.figure(figsize=(12,5))

sns.lineplot(data = ih, x = "Year", y = "NA_Sales", color = "green",marker = "o")
sns.lineplot(data = ba, x = "Year", y = "NA_Sales", color = "orange",marker = "o")

plt.legend(['Ice Hockey','Baseball'])

plt.xticks(ih["Year"], rotation = 45, fontsize = 7, weight = "bold")

plt.grid(alpha = 0.3) ## 30% visibility
plt.title("Trend of Ice Hockey vs Baseball Sales in NA Region")

plt.show()

# %%
plt.figure(figsize=(12,5))

sns.lineplot(data = ih, x = "Year", y = "NA_Sales", color = "green",marker = "o")
sns.lineplot(data = ba, x = "Year", y = "NA_Sales", color = "orange",marker = "o")

plt.legend(['Ice Hockey','Baseball'], loc = "upper left")

plt.xticks(ih["Year"], rotation = 45, fontsize = 7, weight = "bold")

plt.grid(alpha = 0.3) ## 30% visibility
plt.title("Trend of Ice Hockey vs Baseball Sales in NA Region")

plt.show()

# %% [markdown]
# #### Adding Data lables

# %%
plt.figure(figsize=(13,5))

sns.lineplot(data=ih, x="Year", y="NA_Sales", color="green", marker = "o")

plt.legend(['Ice Hockey'])

plt.xticks(ih["Year"])
plt.xticks(rotation = 45, fontsize = 7, weight='bold')
plt.grid(alpha = 0.3)

## add labels

for i, na_sale in enumerate(ih["NA_Sales"]):
    plt.annotate(na_sale, (ih["Year"].values[i], ih["NA_Sales"].values[i]), fontsize = 8)


plt.show()

# %%
my_list = [54,32,76,89,45]

# %%
for i in my_list:
    print(i)
# Out:
# 54
# 32
# 76
# 89
# 45

# %%
for index, actual_value in enumerate(my_list):
    print(index)
    print(actual_value)
    print("")
# Out:
# 0
# 54
#
# 1
# 32
#
# 2
# 76
#
# 3
# 89
#
# 4
# 45

# %% [markdown]
# ### Hue parameter

# %%
data.Genre.nunique()
# Out:
# 12

# %%
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
tdf = data[data["Genre"].isin(["Shooter", "Action"]) & data["Platform"].isin(["PS2", "PS3", "DS"])]

# %%
sns.boxplot(data = tdf, x = "Genre", y = "Global_Sales")
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='Global_Sales'>

# %%
box = sns.boxplot(data = tdf, x = "Genre", y = "Global_Sales", hue = "Platform")

# %%
box.
# Out:
# <bound method Artist.get_cursor_data of <AxesSubplot:xlabel='Genre', ylabel='Global_Sales'>>
