# %% [markdown]
# <a href="https://colab.research.google.com/github/knagabharathi/Pylib_Data_visualization/blob/main/Netflix_case_studies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('netflix_titles.csv')

# %% [markdown]
# #ANALYSING THE BASIC MATRICS

# %% [markdown]
# data set consist of following columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# #DATA PREPROCESSING

# %% [markdown]
# #Unnesting columns
#
# Un-nest the columns those have cells with multiple comma separated values by
# creating multiple rows
#
# list of columns having multiple comma seperated values
#
# 1.director
# 2.cast
# 3.country
# 4.listed_in

# %% [markdown]
# # process -> Split by commas and explode

# %%
dfc = df.copy()

# %%
dfc.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
# converting the columns to str
#df = df.astype(str)
#dfc = dfc.astype(str)

# %%
df_columns = dfc.columns[[3,4,5,10]]
df_columns
# Out:
# Index(['director', 'cast', 'country', 'listed_in'], dtype='object')

# %%
#exploding the columns
for i in df_columns:
  if df[i].str.contains(',').any():
    dfc[i] = df[i].str.split(',')
    dfc = dfc.explode(i)

dfc = dfc.reset_index(drop=True)

# %%
#dfc.drop('index',axis=1, inplace=True)

# %% [markdown]
# # Verify 4 columns exploded or Not

# %%
#return No couput
for i in df_columns:
  if dfc[i].str.contains(',').any():
    print(i)

# return No result - Success

# %% [markdown]
# #2.Identifying the missing values

# %%
dfc
# Out:
#        show_id     type                 title         director  \
# 0           s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1           s2  TV Show         Blood & Water              NaN
# 2           s2  TV Show         Blood & Water              NaN
# 3           s2  TV Show         Blood & Water              NaN
# 4           s2  TV Show         Blood & Water              NaN
# ...        ...      ...                   ...              ...
# 202060   s8807    Movie                Zubaan      Mozez Singh
# 202061   s8807    Movie                Zubaan      Mozez Singh
# 202062   s8807    Movie                Zubaan      Mozez Singh
# 202063   s8807    Movie                Zubaan      Mozez Singh
# 202064   s8807    Movie                Zubaan      Mozez Singh
#
#                           cast        country          date_added  \
# 0                          NaN  United States  September 25, 2021
# 1                   Ama Qamata   South Africa  September 24, 2021
# 2                   Ama Qamata   South Africa  September 24, 2021
# 3                   Ama Qamata   South Africa  September 24, 2021
# 4                  Khosi Ngema   South Africa  September 24, 2021
# ...                        ...            ...                 ...
# 202060          Anita Shabdish          India       March 2, 2019
# 202061          Anita Shabdish          India       March 2, 2019
# 202062   Chittaranjan Tripathy          India       March 2, 2019
# 202063   Chittaranjan Tripathy          India       March 2, 2019
# 202064   Chittaranjan Tripathy          India       March 2, 2019
#
#         release_year rating   duration               listed_in  \
# 0               2020  PG-13     90 min           Documentaries
# 1               2021  TV-MA  2 Seasons  International TV Shows
# 2               2021  TV-MA  2 Seasons               TV Dramas
# 3               2021  TV-MA  2 Seasons            TV Mysteries
# 4               2021  TV-MA  2 Seasons  International TV Shows
# ...              ...    ...        ...                     ...
# 202060          2015  TV-14    111 min    International Movies
# 202061          2015  TV-14    111 min        Music & Musicals
# 202062          2015  TV-14    111 min                  Dramas
# 202063          2015  TV-14    111 min    International Movies
# 202064          2015  TV-14    111 min        Music & Musicals
#
#                                               description
# 0       As her father nears the end of his life, filmm...
# 1       After crossing paths at a party, a Cape Town t...
# 2       After crossing paths at a party, a Cape Town t...
# 3       After crossing paths at a party, a Cape Town t...
# 4       After crossing paths at a party, a Cape Town t...
# ...                                                   ...
# 202060  A scrappy but poor boy worms his way into a ty...
# 202061  A scrappy but poor boy worms his way into a ty...
# 202062  A scrappy but poor boy worms his way into a ty...
# 202063  A scrappy but poor boy worms his way into a ty...
# 202064  A scrappy but poor boy worms his way into a ty...
#
# [202065 rows x 12 columns]

# %%
dfc.isnull().sum()
# Out:
# show_id             0
# type                0
# title               0
# director        50643
# cast             2149
# country         11897
# date_added        158
# release_year        0
# rating             67
# duration            3
# listed_in           0
# description         0
# dtype: int64

# %% [markdown]
# Only director , cast, country, date_added, rating , duration had missing values

# %%
#No need
# replace cast with Unknown in categorical columns - cast ,director, country
column_unknown = ['cast' ,'director', 'country']
df[column_unknown] = df[column_unknown].fillna('Unknown', inplace=True)

# replace null with 0 in continous variable colum - Rating , duration
column_0 = ['rating','duration']
dfc[column_0] = dfc[column_0].fillna(0, inplace=True)
# Out:
# <ipython-input-69-c05c72a7d12c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_unknown] = df[column_unknown].fillna('Unknown', inplace=True)
# <ipython-input-69-c05c72a7d12c>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc[column_0] = dfc[column_0].fillna(0, inplace=True)

# %%
dfc['director'].fillna('Unknown',inplace=True)
dfc['cast'].fillna('Unknown',inplace=True)
dfc['country'].fillna('Unknown',inplace=True)
dfc['rating'].fillna(0,inplace=True)
dfc['duration'].fillna(0,inplace=True)

x = dfc['date_added'].value_counts().idxmax()
dfc['date_added'].fillna(x, inplace=True)

# %%
# change the date type to column - date_added
#dfc['date_added'] = pd.to_datetime(dfc['date_added'])

# %%
#verified - returns 0 for all columns
dfc.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# #Splitted the table for movie and Tv show

# %%
#Splitted the movie and TV shows
dfc_movie = dfc [dfc['type'] == 'Movie'].copy()
dfc_tv = dfc[dfc ['type'] == 'TV Show'].copy()

# %%
dfc_tv.shape
# Out:
# (56148, 12)

# %%
dfc_movie.shape
# Out:
# (145917, 12)

# %%
dfc.shape
# Out:
# (202065, 12)

# %%
# Alter the Duration column
dfc_movie['duration'] = dfc_movie['duration'].str.split().str[0]
dfc_tv['duration'] = dfc_tv['duration'].str.split().str[0]

# %%
dfc_movie.head()
# Out:
#     show_id   type                             title         director  \
# 0        s1  Movie              Dick Johnson Is Dead  Kirsten Johnson
# 159      s7  Movie  My Little Pony: A New Generation    Robert Cullen
# 160      s7  Movie  My Little Pony: A New Generation    Robert Cullen
# 161      s7  Movie  My Little Pony: A New Generation    Robert Cullen
# 162      s7  Movie  My Little Pony: A New Generation    Robert Cullen
#
#                 cast        country          date_added  release_year rating  \
# 0            Unknown  United States  September 25, 2021          2020  PG-13
# 159  Vanessa Hudgens        Unknown  September 24, 2021          2021     PG
# 160     Kimiko Glenn        Unknown  September 24, 2021          2021     PG
# 161    James Marsden        Unknown  September 24, 2021          2021     PG
# 162     Sofia Carson        Unknown  September 24, 2021          2021     PG
#
#     duration                 listed_in  \
# 0         90             Documentaries
# 159       91  Children & Family Movies
# 160       91  Children & Family Movies
# 161       91  Children & Family Movies
# 162       91  Children & Family Movies
#
#                                            description
# 0    As her father nears the end of his life, filmm...
# 159  Equestria's divided. But a bright-eyed hero be...
# 160  Equestria's divided. But a bright-eyed hero be...
# 161  Equestria's divided. But a bright-eyed hero be...
# 162  Equestria's divided. But a bright-eyed hero be...

# %%
dfc_tv.head()
# Out:
#   show_id     type          title director          cast       country  \
# 1      s2  TV Show  Blood & Water  Unknown    Ama Qamata  South Africa
# 2      s2  TV Show  Blood & Water  Unknown    Ama Qamata  South Africa
# 3      s2  TV Show  Blood & Water  Unknown    Ama Qamata  South Africa
# 4      s2  TV Show  Blood & Water  Unknown   Khosi Ngema  South Africa
# 5      s2  TV Show  Blood & Water  Unknown   Khosi Ngema  South Africa
#
#            date_added  release_year rating duration               listed_in  \
# 1  September 24, 2021          2021  TV-MA        2  International TV Shows
# 2  September 24, 2021          2021  TV-MA        2               TV Dramas
# 3  September 24, 2021          2021  TV-MA        2            TV Mysteries
# 4  September 24, 2021          2021  TV-MA        2  International TV Shows
# 5  September 24, 2021          2021  TV-MA        2               TV Dramas
#
#                                          description
# 1  After crossing paths at a party, a Cape Town t...
# 2  After crossing paths at a party, a Cape Town t...
# 3  After crossing paths at a party, a Cape Town t...
# 4  After crossing paths at a party, a Cape Town t...
# 5  After crossing paths at a party, a Cape Town t...

# %% [markdown]
# #diversity of datasets

# %%
print(dfc_movie['title'].nunique()) # 6137 unique movies are there
print(dfc_tv['title'].nunique()) # 2676 TV shows are there
print(dfc['director'].nunique()) # 5121 directors are there

print(dfc_movie['director'].nunique()) # 4887 director directed movies
print(dfc_tv['director'].nunique()) # 301 director directed TV shows

directed_both = set(dfc_movie['director']) & set(dfc_tv['director'])
len(directed_both)

# 67 directors make both movies and tv shows
# Out:
# 6131
# 2676
# 5121
# 4887
# 301
# 67

# %% [markdown]
# Cast of TV shows

# %%
print(dfc_movie['cast'].nunique()) # 27880
print(dfc_tv['cast'].nunique()) # 15502
print(dfc['cast'].nunique()) # 39297

casted_both = set(dfc_movie['cast']) & set(dfc_tv['cast'])
len(casted_both) # 4085 casted in both TV shows and Movies
# Out:
# 27880
# 15502
# 39297
# 4085

# %% [markdown]
# #Country wise TV and MOvies

# %%
print(dfc['country'].nunique()) # 198 total unique contries
print(dfc_movie['country'].nunique()) # 188
print(dfc_tv['country'].nunique()) # 103

combined_set  = set(dfc_movie['country']) & set(dfc_tv['country'])
len(combined_set)
 # 93 countries produced both movies and tV shows
# Out:
# 198
# 188
# 103
# 93

# %% [markdown]
# #geners in movies

# %%
dfc_movie['listed_in'].value_counts()
# Out:
#  International Movies        27141
# Dramas                       19657
# Comedies                     13894
# Action & Adventure           12216
#  Dramas                      10149
#  Independent Movies           9564
# Children & Family Movies      9294
#  Comedies                     6935
#  Romantic Movies              6392
#  Thrillers                    6283
#  Sci-Fi & Fantasy             3875
# Horror Movies                 3259
#  Music & Musicals             3012
# Documentaries                 2285
#  Sports Movies                1528
#  Horror Movies                1312
# International Movies          1102
# Classic Movies                 946
#  Cult Movies                   908
#  LGBTQ Movies                  833
# Thrillers                      824
#  Anime Features                765
#  Faith & Spirituality          719
# Stand-Up Comedy                516
#  Classic Movies                497
#  Children & Family Movies      477
# Movies                         412
# Anime Features                 280
# Independent Movies             270
# Cult Movies                    169
# Sci-Fi & Fantasy               162
#  Documentaries                 124
# Music & Musicals                65
#  Stand-Up Comedy                24
# Romantic Movies                 20
# LGBTQ Movies                     5
# Sports Movies                    3
# Name: listed_in, dtype: int64

# %% [markdown]
# #genres in TV shows

# %%
dfc_tv['listed_in'].value_counts()
# Out:
#  TV Dramas                       7956
# International TV Shows           7065
#  International TV Shows          5780
# Crime TV Shows                   4020
# Kids' TV                         3809
#  TV Comedies                     3768
#  Romantic TV Shows               2729
# Anime Series                     2313
#  Spanish-Language TV Shows       2088
# British TV Shows                 1808
#  TV Action & Adventure           1724
#  TV Mysteries                    1281
# TV Comedies                      1195
#  Korean TV Shows                 1122
#  TV Sci-Fi & Fantasy             1038
# TV Dramas                         986
#  TV Thrillers                     768
#  Kids' TV                         759
#  TV Horror                        750
#  Teen TV Shows                    742
#  Crime TV Shows                   713
# TV Action & Adventure             564
# Docuseries                        546
# Reality TV                        413
# TV Shows                          337
#  Reality TV                       322
# Romantic TV Shows                 320
#  Docuseries                       299
# Classic & Cult TV                 236
# TV Horror                         191
# Stand-Up Comedy & Talk Shows      188
#  Science & Nature TV              157
#  Stand-Up Comedy & Talk Shows      80
# Spanish-Language TV Shows          38
#  Classic & Cult TV                 36
# TV Sci-Fi & Fantasy                 7
# Name: listed_in, dtype: int64

# %% [markdown]
# # continous variable exploration

# %% [markdown]
# count of movies in each genre

# %%
gen_count = dfc_movie['listed_in'].value_counts()[:20]
x = gen_count.index
y = gen_count.values

# %%
plt.figure(figsize=(12,5))
plt.bar(x,y,color='red')
plt.title('Count of movies in each genre')
plt.xlabel('genre',fontsize = 12)
plt.ylabel('Count',fontsize = 12)

plt.xticks(fontsize = 7,rotation = 45)
plt.show()

#International movies, Dramas , comedy's are the Top 3 genres of Movies in Netflix

# %% [markdown]
# count TV shows in each genre

# %%
tv_gen = dfc_tv['listed_in'].value_counts()[:20]
x = tv_gen.index
y = tv_gen.values

# %%
plt.figure(figsize = (11,5))
plt.bar(x,y,color='red')
plt.title('Count TV shows in each genre')
plt.xlabel('genre',fontsize = 12)
plt.ylabel('Count',fontsize = 12)

plt.xticks(rotation = 45,fontsize= 7)
plt.show()

#Tv Dramas , International TV shows, crime TV shows are the Top 3 genres of Tv shows in netflix

# %%
release_cnt = dfc_movie['release_year'].value_counts()
x = release_cnt.index
y = release_cnt.values


plt.figure(figsize = (11,5))
plt.bar(x,y,color='red')
plt.title('Count of movies over year')
plt.xlabel('Year',fontsize = 12)
plt.ylabel('Count',fontsize = 12)

plt.xticks(rotation = 45,fontsize= 7)
plt.show()

# %%
release_cnt = dfc_tv['release_year'].value_counts()
x = release_cnt.index
y = release_cnt.values


plt.figure(figsize = (11,5))
plt.bar(x,y,color='red')
plt.title('Count of TV over year')
plt.xlabel('Year',fontsize = 12)
plt.ylabel('Count',fontsize = 12)

plt.xticks(rotation = 45,fontsize= 7)
plt.show()

# last 7 years , TV shows become so popular

# %% [markdown]
# #Distribution

# %%
dfc_movie['duration']
# Out:
# 0          90
# 159        91
# 160        91
# 161        91
# 162        91
#          ...
# 202060    111
# 202061    111
# 202062    111
# 202063    111
# 202064    111
# Name: duration, Length: 145917, dtype: object

# %%
#change the data type to int - > to plot Histogram

#dfc_movie['duration'].isnull().sum()
dfc_movie['duration'].fillna(0,inplace=True)
dfc_movie['duration'] = dfc_movie['duration'].astype(int)

# %%
sns.histplot(dfc_movie['duration'],binwidth= 5, kde= True, color ='red')

#Most of movies falls between 80 to 140 minuets
# Out:
# <Axes: xlabel='duration', ylabel='Count'>

# %% [markdown]
# distribution of TV shows

# %%
dfc_tv['duration'].fillna(0,inplace=True)
dfc_tv['duration'] = dfc_tv['duration'].astype(int)
sns.histplot(dfc_tv['duration'],kde=True,color='red')

# Most of Tv shows only had 1 and 2 seasons
# Out:
# <Axes: xlabel='duration', ylabel='Count'>

# %% [markdown]
# Number of movies produced in each country - Top 10

# %%
cun  = dfc_movie['country'].value_counts()[:10]
x = cun.index
y = cun.values

plt.figure(figsize = (11,5))
plt.bar(x,y,color='red')
plt.title('Movie produced by each country')
plt.xlabel('Country',fontsize = 12)
plt.ylabel('Count',fontsize = 12)

plt.xticks(rotation = 45,fontsize= 7)
plt.show()

#united states, India, France make more films

# %%
cun  = dfc_tv['country'].value_counts()[:10]
x = cun.index
y = cun.values

plt.figure(figsize = (11,5))
plt.bar(x,y,color='red')
plt.title('Tv shows produced by each country')
plt.xlabel('Country',fontsize = 12)
plt.ylabel('Count',fontsize = 12)

plt.xticks(rotation = 45,fontsize= 7)
plt.show()

#United states , Japan, UK , South korea makes more TV shows

# %%
cun1  = dfc_movie['country'].value_counts()[:10]
#x1 = cun1.index
#y1 = cun1.values

cun2  = dfc_tv['country'].value_counts()[:10]
#x2 = cun2.index
#y2 = cun2.values'''

combined_df = pd.DataFrame({'Country': cun1.index,
                            'Movies': cun1.values,
                            'TV Shows': cun2.values})

plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")
sns.barplot(data=combined_df, x='Country', y='Movies', color='skyblue', label='Movies')
sns.barplot(data=combined_df, x='Country', y='TV Shows', color='orange', label='TV Shows')
plt.xlabel('Country')
plt.ylabel('Number of Productions')
plt.title('Comparison of Movies and TV Shows by Country')
plt.xticks(rotation=45)
plt.legend()
plt.xticks(rotation = 45,fontsize= 7)
plt.tight_layout()
plt.show()

# %% [markdown]
# #Top 3 weeks to release movies and TV shows

# %%
dfc_movie['date_added'] = pd.to_datetime(dfc_movie['date_added'])

dfc_movie['release_week'] = dfc_movie['date_added'].dt.week

# %%
dfc_movie['release_week'].value_counts()[:10]
# Out:
# 1     8456
# 44    5563
# 9     5094
# 35    5048
# 26    4931
# 40    4905
# 31    4388
# 27    3808
# 48    3737
# 18    3686
# Name: release_week, dtype: int64

# %%
sns.histplot(data= dfc_movie, x= 'release_week', bins= 52)
plt.title('Distribution of Movie Releases by Week')

#1,44,9 the week were the TOP major 3 weeks to release the movies
# Out:
# Text(0.5, 1.0, 'Distribution of Movie Releases by Week')

# %%
dfc_tv['date_added'] = pd.to_datetime(dfc_tv['date_added'])

dfc_tv['release_week'] = dfc_tv['date_added'].dt.week
# Out:
# <ipython-input-50-4da0a1bc8751>:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   dfc_tv['release_week'] = dfc_tv['date_added'].dt.week

# %%
dfc_tv['release_week'].value_counts()[:10]
# Out:
# 27    1977
# 35    1945
# 24    1702
# 26    1662
# 31    1646
# 13    1554
# 48    1513
# 5     1386
# 44    1380
# 18    1364
# Name: release_week, dtype: int64

# %%
sns.histplot(data= dfc_tv, x= 'release_week', bins= 52)
plt.title('Distribution of Tvshows Releases by Week')

# 27 , 35, 24 the week were the TOP major 3 weeks to release the Tv shows
# Out:
# Text(0.5, 1.0, 'Distribution of Tvshows Releases by Week')

# %%
dfc_movie['month_release'] = dfc_movie['date_added'].dt.month_name()
dfc_movie.drop('month_release', axis =1, inplace=True)

# %%
dfc_movie.drop('month_release', axis =1, inplace=True)

# %%
dfc_movie['month_release'].value_counts()
# Out:
# July         15075
# January      13947
# October      13541
# September    13220
# December     12768
# April        12538
# August       11924
# June         11616
# March        11507
# November     11065
# May           9579
# February      9137
# Name: month_release, dtype: int64

# %%
sns.histplot(data= dfc_movie, x='month_release',color='red')
sns.color_palette("flare", as_cmap=True)

plt.title('Release movie based on month')
plt.xlabel('month')
plt.ylabel('count')
plt.xticks(rotation=45, fontsize=9)
#plt.legend(title='Gender')
plt.show()

#July, January October were the Top 3 months to release films

# %%
dfc_tv['month_release'] = dfc_tv['date_added'].dt.month_name()
#dfc_tv.drop('month_release', axis =1, inplace=True)

# %%
dfc_tv['month_release'].value_counts()
# Out:
# December     5498
# July         5227
# August       5162
# June         5043
# September    4900
# April        4543
# November     4532
# January      4465
# March        4352
# October      4255
# May          4248
# February     3923
# Name: month_release, dtype: int64

# %%
sns.histplot(data= dfc_tv, x='month_release',color='red')
sns.color_palette("flare", as_cmap=True)

plt.title('Release movie based on month')
plt.xlabel('month')
plt.ylabel('count')
plt.xticks(rotation=45, fontsize=9)
#plt.legend(title='Gender')
plt.show()

#December, July,  Auguest were the Top 3 months to release TV shows

# %% [markdown]
# #Top 10 actors who have appeared in Movies

# %%
x = dfc_tv.groupby('cast').agg(val=('title', 'nunique'))

# %%
x.drop('Unknown',inplace=True)

# %%
l = x.sort_values(by='val', ascending=False)[:10]

# %%
l =l.reset_index()

# %%
plt.figure(figsize=(10, 6))
plt.title('Top 10 actors who have appeared in most of Tv shows')

sns.barplot(data=l, x="cast" , y = 'val')

plt.xticks(rotation=45,fontsize=7)
plt.show()

# %%
#movies

x = dfc_movie.groupby('cast').agg(val=('title', 'nunique'))
x.drop('Unknown',inplace=True)
m = x.sort_values(by='val', ascending=False)[:10]

# %%
m = m.reset_index()

# %%
plt.figure(figsize=(10, 6))

plt.title('Top 10 actors who have appeared in most of Movies')
sns.barplot(data=m, x="cast" , y = 'val')

plt.xticks(rotation=45,fontsize=7)
plt.show()

# %% [markdown]
# #Top 10 directors take more films

# %%
x = dfc_movie.groupby('director').agg(count = ('title','nunique'))
x.drop('Unknown',inplace=True)
x = x.reset_index()
m = x.sort_values(by='count', ascending=False)[:10]

# %%
plt.figure(figsize=(10, 6))

plt.title('Top 10 directors take more films ')
sns.barplot(data=m[:10], x="director" , y = 'count')

plt.xticks(rotation=45,fontsize=7)
plt.show()

# %%
x = dfc_tv.groupby('director').agg(count = ('title','nunique'))
x.drop('Unknown',inplace=True)
x = x.reset_index()
m = x.sort_values(by='count', ascending=False)[:10]

# %%
plt.figure(figsize=(10, 6))

plt.title('Top 10 directors take more TV shows ')
sns.barplot(data=m, x="director" , y = 'count')

plt.xticks(rotation=45,fontsize=7)
plt.show()

# %% [markdown]
# #Genres movies more popular

# %%
dfc_movie['listed_in']
# Out:
# 0                    Documentaries
# 159       Children & Family Movies
# 160       Children & Family Movies
# 161       Children & Family Movies
# 162       Children & Family Movies
#                     ...
# 202060        International Movies
# 202061            Music & Musicals
# 202062                      Dramas
# 202063        International Movies
# 202064            Music & Musicals
# Name: listed_in, Length: 145917, dtype: object

# %%
l =dfc_movie.groupby('listed_in').agg(count= ('title','nunique')).reset_index().sort_values(by='count', ascending=False)[:10]

# %%
plt.figure(figsize=(10, 6))

plt.title('Genres movies more popular')
sns.barplot(data=l, x="listed_in" , y = 'count')

plt.xticks(rotation=45,fontsize=7)
plt.show()

# International movies, dramas, comedy movies are more popular

# %%
l =dfc_tv.groupby('listed_in').agg(count= ('title','nunique')).reset_index().sort_values(by='count', ascending=False)[:10]

# %%
plt.figure(figsize=(10, 6))

plt.title('Genres TV shows more popular')
sns.barplot(data=l, x="listed_in" , y = 'count')

plt.xticks(rotation=45,fontsize=7)
plt.show()


#International TV shows , TV dramas, TV comedies were more popular

# %%
dfc_movie.head()
# Out:
#     show_id   type                             title         director  \
# 0        s1  Movie              Dick Johnson Is Dead  Kirsten Johnson
# 159      s7  Movie  My Little Pony: A New Generation    Robert Cullen
# 160      s7  Movie  My Little Pony: A New Generation    Robert Cullen
# 161      s7  Movie  My Little Pony: A New Generation    Robert Cullen
# 162      s7  Movie  My Little Pony: A New Generation    Robert Cullen
#
#                 cast        country          date_added  release_year rating  \
# 0            Unknown  United States  September 25, 2021          2020  PG-13
# 159  Vanessa Hudgens        Unknown  September 24, 2021          2021     PG
# 160     Kimiko Glenn        Unknown  September 24, 2021          2021     PG
# 161    James Marsden        Unknown  September 24, 2021          2021     PG
# 162     Sofia Carson        Unknown  September 24, 2021          2021     PG
#
#     duration                 listed_in  \
# 0         90             Documentaries
# 159       91  Children & Family Movies
# 160       91  Children & Family Movies
# 161       91  Children & Family Movies
# 162       91  Children & Family Movies
#
#                                            description
# 0    As her father nears the end of his life, filmm...
# 159  Equestria's divided. But a bright-eyed hero be...
# 160  Equestria's divided. But a bright-eyed hero be...
# 161  Equestria's divided. But a bright-eyed hero be...
# 162  Equestria's divided. But a bright-eyed hero be...

# %%
dfc_movie['date_added'] = pd.to_datetime (dfc_movie['date_added'] ) #- pd.to_datetime (dfc_movie['release_year'])) / np.timedelta64(1, 'D')

# %%
dfc_movie['release_year'] = pd.to_datetime(dfc_movie['release_year'])
dfc_movie['release_year'] = dfc_movie['release_year'].dt.strftime('%Y-%m-%d')
dfc_movie['release_year'] = pd.to_datetime(dfc_movie['release_year'])

dfc_movie['date_count'] =  (dfc_movie['date_added'] - dfc_movie['release_year']) / np.timedelta64(1, 'D')

# %%
dfc_movie.head()
# Out:
#     show_id   type                             title         director  \
# 0        s1  Movie              Dick Johnson Is Dead  Kirsten Johnson
# 159      s7  Movie  My Little Pony: A New Generation    Robert Cullen
# 160      s7  Movie  My Little Pony: A New Generation    Robert Cullen
# 161      s7  Movie  My Little Pony: A New Generation    Robert Cullen
# 162      s7  Movie  My Little Pony: A New Generation    Robert Cullen
#
#                 cast        country date_added release_year rating duration  \
# 0            Unknown  United States 2021-09-25   1970-01-01  PG-13       90
# 159  Vanessa Hudgens        Unknown 2021-09-24   1970-01-01     PG       91
# 160     Kimiko Glenn        Unknown 2021-09-24   1970-01-01     PG       91
# 161    James Marsden        Unknown 2021-09-24   1970-01-01     PG       91
# 162     Sofia Carson        Unknown 2021-09-24   1970-01-01     PG       91
#
#                     listed_in  \
# 0               Documentaries
# 159  Children & Family Movies
# 160  Children & Family Movies
# 161  Children & Family Movies
# 162  Children & Family Movies
#
#                                            description  date_count
# 0    As her father nears the end of his life, filmm...     18895.0
# 159  Equestria's divided. But a bright-eyed hero be...     18894.0
# 160  Equestria's divided. But a bright-eyed hero be...     18894.0
# 161  Equestria's divided. But a bright-eyed hero be...     18894.0
# 162  Equestria's divided. But a bright-eyed hero be...     18894.0

# %%
dfc_movie.groupby('title').agg(dats = ('date_count','max')).sort_values(by='dats', ascending =False).reset_index()
# Out:
#                                  title     dats
# 0                 Dick Johnson Is Dead  18895.0
# 1                         The Starling  18894.0
# 2     My Little Pony: A New Generation  18894.0
# 3                              Sankofa  18894.0
# 4                         Je Suis Karl  18893.0
# ...                                ...      ...
# 6126                     Even the Rain  15111.0
# 6127       Mad Ron's Prevues from Hell  14914.0
# 6128                          Splatter  14566.0
# 6129           Just Another Love Story  14369.0
# 6130              To and From New York  13879.0
#
# [6131 rows x 2 columns]

# %%
dfc_tv.head()
# Out:
#   show_id     type          title director          cast       country  \
# 1      s2  TV Show  Blood & Water  Unknown    Ama Qamata  South Africa
# 2      s2  TV Show  Blood & Water  Unknown    Ama Qamata  South Africa
# 3      s2  TV Show  Blood & Water  Unknown    Ama Qamata  South Africa
# 4      s2  TV Show  Blood & Water  Unknown   Khosi Ngema  South Africa
# 5      s2  TV Show  Blood & Water  Unknown   Khosi Ngema  South Africa
#
#            date_added release_year rating duration               listed_in  \
# 1  September 24, 2021   1970-01-01  TV-MA        2  International TV Shows
# 2  September 24, 2021   1970-01-01  TV-MA        2               TV Dramas
# 3  September 24, 2021   1970-01-01  TV-MA        2            TV Mysteries
# 4  September 24, 2021   1970-01-01  TV-MA        2  International TV Shows
# 5  September 24, 2021   1970-01-01  TV-MA        2               TV Dramas
#
#                                          description
# 1  After crossing paths at a party, a Cape Town t...
# 2  After crossing paths at a party, a Cape Town t...
# 3  After crossing paths at a party, a Cape Town t...
# 4  After crossing paths at a party, a Cape Town t...
# 5  After crossing paths at a party, a Cape Town t...

# %%
dfc_tv['date_added'] = pd.to_datetime(dfc_tv['date_added'])

# %%
dfc_tv['release_year'] = pd.to_datetime(dfc_tv['release_year'])
dfc_tv['release_year'] = dfc_tv['release_year'].dt.strftime('%Y-%m-%d')
dfc_tv['release_year'] = pd.to_datetime(dfc_tv['release_year'])

dfc_tv['date_count'] =  (dfc_tv['date_added'] - dfc_tv['release_year']) / np.timedelta64(1, 'D')

# %%
dfc_tv.head()
# Out:
#   show_id     type          title director          cast       country  \
# 1      s2  TV Show  Blood & Water  Unknown    Ama Qamata  South Africa
# 2      s2  TV Show  Blood & Water  Unknown    Ama Qamata  South Africa
# 3      s2  TV Show  Blood & Water  Unknown    Ama Qamata  South Africa
# 4      s2  TV Show  Blood & Water  Unknown   Khosi Ngema  South Africa
# 5      s2  TV Show  Blood & Water  Unknown   Khosi Ngema  South Africa
#
#   date_added release_year rating duration               listed_in  \
# 1 2021-09-24   1970-01-01  TV-MA        2  International TV Shows
# 2 2021-09-24   1970-01-01  TV-MA        2               TV Dramas
# 3 2021-09-24   1970-01-01  TV-MA        2            TV Mysteries
# 4 2021-09-24   1970-01-01  TV-MA        2  International TV Shows
# 5 2021-09-24   1970-01-01  TV-MA        2               TV Dramas
#
#                                          description  date_count
# 1  After crossing paths at a party, a Cape Town t...     18894.0
# 2  After crossing paths at a party, a Cape Town t...     18894.0
# 3  After crossing paths at a party, a Cape Town t...     18894.0
# 4  After crossing paths at a party, a Cape Town t...     18894.0
# 5  After crossing paths at a party, a Cape Town t...     18894.0
